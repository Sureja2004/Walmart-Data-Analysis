# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Excel\\Walmart.csv")
df['unit_price'] = df['unit_price'].str.replace('$','',regex=False)

# %%
df["unit_price"] = pd.to_numeric(df["unit_price"],errors = 'coerce')

# %%
df
# Out:
#       invoice_id   Branch         City                category  unit_price  \
# 0              1  WALM003  San Antonio       Health and beauty       74.69
# 1              2  WALM048    Harlingen  Electronic accessories       15.28
# 2              3  WALM067  Haltom City      Home and lifestyle       46.33
# 3              4  WALM064      Bedford       Health and beauty       58.22
# 4              5  WALM013       Irving       Sports and travel       86.31
# ...          ...      ...          ...                     ...         ...
# 9995        9996  WALM056      Rowlett     Fashion accessories       37.00
# 9996        9997  WALM030   Richardson      Home and lifestyle       58.00
# 9997        9998  WALM050     Victoria     Fashion accessories       52.00
# 9998        9999  WALM032        Tyler      Home and lifestyle       79.00
# 9999       10000  WALM069     Rockwall     Fashion accessories       62.00
#
#       quantity        date      time payment_method  rating  profit_margin
# 0          7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1          5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2          7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3          8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4          7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48
# ...        ...         ...       ...            ...     ...            ...
# 9995       3.0  2023-08-03  10:10:00           Cash     3.0           0.33
# 9996       2.0  2021-02-22  14:20:00           Cash     7.0           0.48
# 9997       3.0  2023-06-15  16:00:00    Credit card     4.0           0.48
# 9998       2.0  2021-02-25  12:25:00           Cash     7.0           0.48
# 9999       3.0  2020-09-26  09:48:00           Cash     3.0           0.33
#
# [10000 rows x 11 columns]

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.describe()
# Out:
#         invoice_id   unit_price     quantity        rating  profit_margin
# count  10000.00000  9969.000000  9969.000000  10000.000000   10000.000000
# mean    5000.50000    50.622142     2.355602      5.830170       0.393813
# std     2886.89568    21.203766     1.605455      1.764097       0.090656
# min        1.00000    10.080000     1.000000      3.000000       0.180000
# 25%     2500.75000    32.000000     1.000000      4.000000       0.330000
# 50%     5000.50000    51.000000     2.000000      6.000000       0.330000
# 75%     7500.25000    69.000000     3.000000      7.000000       0.480000
# max    10000.00000    99.960000    10.000000     10.000000       0.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10000 non-null  int64
#  1   Branch          10000 non-null  object
#  2   City            10000 non-null  object
#  3   category        10000 non-null  object
#  4   unit_price      9969 non-null   float64
#  5   quantity        9969 non-null   float64
#  6   date            10000 non-null  object
#  7   time            10000 non-null  object
#  8   payment_method  10000 non-null  object
#  9   rating          10000 non-null  float64
#  10  profit_margin   10000 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 937.5+ KB

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity        date      time payment_method  rating  profit_margin
# 0       7.0  2019-01-05  13:08:00        Ewallet     9.1           0.48
# 1       5.0  2019-03-08  10:29:00           Cash     9.6           0.48
# 2       7.0  2019-03-03  13:23:00    Credit card     7.4           0.33
# 3       8.0  2019-01-27  20:33:00        Ewallet     8.4           0.33
# 4       7.0  2019-02-08  10:37:00        Ewallet     5.3           0.48

# %%
df.tail()
# Out:
#       invoice_id   Branch        City             category  unit_price  \
# 9995        9996  WALM056     Rowlett  Fashion accessories        37.0
# 9996        9997  WALM030  Richardson   Home and lifestyle        58.0
# 9997        9998  WALM050    Victoria  Fashion accessories        52.0
# 9998        9999  WALM032       Tyler   Home and lifestyle        79.0
# 9999       10000  WALM069    Rockwall  Fashion accessories        62.0
#
#       quantity        date      time payment_method  rating  profit_margin
# 9995       3.0  2023-08-03  10:10:00           Cash     3.0           0.33
# 9996       2.0  2021-02-22  14:20:00           Cash     7.0           0.48
# 9997       3.0  2023-06-15  16:00:00    Credit card     4.0           0.48
# 9998       2.0  2021-02-25  12:25:00           Cash     7.0           0.48
# 9999       3.0  2020-09-26  09:48:00           Cash     3.0           0.33

# %%
df.set_index("invoice_id")
# Out:
#              Branch         City                category  unit_price  \
# invoice_id
# 1           WALM003  San Antonio       Health and beauty       74.69
# 2           WALM048    Harlingen  Electronic accessories       15.28
# 3           WALM067  Haltom City      Home and lifestyle       46.33
# 4           WALM064      Bedford       Health and beauty       58.22
# 5           WALM013       Irving       Sports and travel       86.31
# ...             ...          ...                     ...         ...
# 9996        WALM056      Rowlett     Fashion accessories       37.00
# 9997        WALM030   Richardson      Home and lifestyle       58.00
# 9998        WALM050     Victoria     Fashion accessories       52.00
# 9999        WALM032        Tyler      Home and lifestyle       79.00
# 10000       WALM069     Rockwall     Fashion accessories       62.00
#
#             quantity        date      time payment_method  rating  \
# invoice_id
# 1                7.0  2019-01-05  13:08:00        Ewallet     9.1
# 2                5.0  2019-03-08  10:29:00           Cash     9.6
# 3                7.0  2019-03-03  13:23:00    Credit card     7.4
# 4                8.0  2019-01-27  20:33:00        Ewallet     8.4
# 5                7.0  2019-02-08  10:37:00        Ewallet     5.3
# ...              ...         ...       ...            ...     ...
# 9996             3.0  2023-08-03  10:10:00           Cash     3.0
# 9997             2.0  2021-02-22  14:20:00           Cash     7.0
# 9998             3.0  2023-06-15  16:00:00    Credit card     4.0
# 9999             2.0  2021-02-25  12:25:00           Cash     7.0
# 10000            3.0  2020-09-26  09:48:00           Cash     3.0
#
#             profit_margin
# invoice_id
# 1                    0.48
# 2                    0.48
# 3                    0.33
# 4                    0.33
# 5                    0.48
# ...                   ...
# 9996                 0.33
# 9997                 0.48
# 9998                 0.48
# 9999                 0.48
# 10000                0.33
#
# [10000 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Removing duplicates
df.drop_duplicates(inplace = True)

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (10000, 11)

# %%
# Drop Null Values
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price        float64
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %%
df["total
